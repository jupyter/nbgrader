# %% [markdown]
# # `nbgrader formgrade`

# %%
# !nbgrader formgrade --help-all
# Out:
# Grade a notebook using an HTML form
#
# Options
# -------
#
# Arguments that take values are actually convenience aliases to full
# Configurables, whose aliases are listed on the help line. For more information
# on full configurables, see '--help-all'.
#
# --ip=<Unicode> (FormgradeApp.ip)
#     Default: 'localhost'
#     IP address for the server
# --port=<Integer> (FormgradeApp.port)
#     Default: 5000
#     Port for the server
#
# Class parameters
# ----------------
#
# Parameters are set from command-line arguments of the form:
# `--Class.trait=value`. This line is evaluated in Python, so simple expressions
# are allowed, e.g.:: `--C.a='range(3)'` For setting C.a=[0,1,2].
#
# FormgradeApp options
# --------------------
# --FormgradeApp.auto_create=<Bool>
#     Default: False
#     Whether to create profile dir if it doesn't exist
# --FormgradeApp.base_directory=<Unicode>
#     Default: '.'
#     Root server directory
# --FormgradeApp.copy_config_files=<Bool>
# ...
