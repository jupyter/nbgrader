# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
print("Success!")

# %%
assert a == 1

# %% [markdown]
# YOUR ANSWER HERE

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
#print("Don't change this cell!")

# %% [markdown]
# This cell shouldn't
# be changed.
